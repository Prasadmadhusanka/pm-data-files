# %%
pip install pandas openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import json

# %%
# Load Excel file
file_path = "../excel_files/Skills_details.xlsx"
df = pd.read_excel(file_path, sheet_name='top_skills')
df
# Out:
#                         skill  percentage  \
# 0      JavaScript (ES5/ ES6+)          95
# 1                      Python          95
# 2                    React.js          90
# 3                      Vue.js          90
# 4                     Node.js          85
# 5                     FastAPI          85
# 6                   Bootstrap          90
# 7          PostgreSQL/PostGIS          95
# 8                     MongoDB          90
# 9                  Leaflet.js          95
# 10                 OpenLayers          95
# 11  ArcGIS Pro, ArcGIS Online          95
# 12                  Geoserver          85
# 13                FME Desktop          90
#
#                                              icon_url icon_color
# 0   https://raw.githubusercontent.com/Prasadmadhus...    #eaca31
# 1   https://raw.githubusercontent.com/Prasadmadhus...    #ffd343
# 2   https://raw.githubusercontent.com/Prasadmadhus...    #61dafb
# 3   https://raw.githubusercontent.com/Prasadmadhus...    #41b883
# ...

# %%
df.columns.values
# Out:
# array(['skill', 'percentage', 'icon_url', 'icon_color'], dtype=object)

# %%
# Convert DataFrame to JSON
json_data = df.to_dict(orient="records")
json_data
# Out:
# [{'skill': 'JavaScript (ES5/ ES6+)',
#   'percentage': 95,
#   'icon_url': 'https://raw.githubusercontent.com/Prasadmadhusanka/pm-data-files/main/images/top_skills_logos/JavaScriptEs5ES6.png',
#   'icon_color': '#eaca31'},
#  {'skill': 'Python',
#   'percentage': 95,
#   'icon_url': 'https://raw.githubusercontent.com/Prasadmadhusanka/pm-data-files/main/images/top_skills_logos/Python.png',
#   'icon_color': '#ffd343'},
#  {'skill': 'React.js',
#   'percentage': 90,
#   'icon_url': 'https://raw.githubusercontent.com/Prasadmadhusanka/pm-data-files/main/images/top_skills_logos/Reactjs.png',
#   'icon_color': '#61dafb'},
#  {'skill': 'Vue.js',
#   'percentage': 90,
#   'icon_url': 'https://raw.githubusercontent.com/Prasadmadhusanka/pm-data-files/main/images/top_skills_logos/Vuejs.png',
#   'icon_color': '#41b883'},
#  {'skill': 'Node.js',
#   'percentage': 85,
#   'icon_url': 'https://raw.githubusercontent.com/Prasadmadhusanka/pm-data-files/main/images/top_skills_logos/Nodejs.png',
# ...

# %%
# Save to JSON file
with open("../json_files/top_skills_details.json", "w", encoding="utf-8") as json_file:
    json.dump(json_data, json_file, indent=4)
