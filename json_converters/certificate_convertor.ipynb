# %%
pip install pandas openpyxl
# Out:
# Requirement already satisfied: pandas in c:\users\prasa\appdata\local\programs\python\python312\lib\site-packages (2.2.3)
# Requirement already satisfied: openpyxl in c:\users\prasa\appdata\local\programs\python\python312\lib\site-packages (3.1.5)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\prasa\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2.1.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\prasa\appdata\roaming\python\python312\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\prasa\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\prasa\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: et-xmlfile in c:\users\prasa\appdata\local\programs\python\python312\lib\site-packages (from openpyxl) (2.0.0)
# Requirement already satisfied: six>=1.5 in c:\users\prasa\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 25.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import json

# %%
# Load Excel file
file_path = "../excel_files/Licenses_Certificates_details.xlsx"
df = pd.read_excel(file_path)
df = df.fillna("")
df
# Out:
#     id                                               logo  \
# 0    1  https://raw.githubusercontent.com/Prasadmadhus...
# 1    2  https://raw.githubusercontent.com/Prasadmadhus...
# 2    3  https://raw.githubusercontent.com/Prasadmadhus...
# 3    4  https://raw.githubusercontent.com/Prasadmadhus...
# 4    5  https://raw.githubusercontent.com/Prasadmadhus...
# 5    6  https://raw.githubusercontent.com/Prasadmadhus...
# 6    7  https://raw.githubusercontent.com/Prasadmadhus...
# 7    8  https://raw.githubusercontent.com/Prasadmadhus...
# 8    9  https://raw.githubusercontent.com/Prasadmadhus...
# 9   10  https://raw.githubusercontent.com/Prasadmadhus...
# 10  11  https://raw.githubusercontent.com/Prasadmadhus...
# 11  12  https://raw.githubusercontent.com/Prasadmadhus...
# 12  13  https://raw.githubusercontent.com/Prasadmadhus...
# 13  14  https://raw.githubusercontent.com/Prasadmadhus...
#
#                                                  name  \
# 0        UAS Remote Pilot A2 Competency Certification
# 1     UAS Remote Pilot A1/A3 Competency Certification
# 2              FME Desktop: Data Translation for\nAEC
# 3   Meta Front - End Developer Professional Certif...
# 4                                      Advanced React
# 5                  Geo Web App Building with OS Tools
# 6          Make an Impact with Modern Geo Apps - MOOC
# 7           IBM Data Science Professional Certificate
# 8                                  Cartography - MOOC
# 9                       GIS for Climate Action - MOOC
# 10  Spatial Data Science: The New Frontier in Anal...
# 11                                 Python Programming
# 12                        Front - End Web Development
# 13             OpenStreetMap and Humanitarian Mapping
#
#                      issued_by  \
# 0                         EASA
# 1                         EASA
# 2                     LinkedIn
# 3                         Meta
# 4                         Meta
# 5   ITC - University of Twente
# 6                         Esri
# 7                          IBM
# 8                         Esri
# 9                         Esri
# 10                        Esri
# 11      University of Moratuwa
# 12      University of Moratuwa
# 13                  UN Mappers
#
#                                       certificate_url credential_id_status  \
# 0   https://raw.githubusercontent.com/Prasadmadhus...                   No
# 1   https://raw.githubusercontent.com/Prasadmadhus...                   No
# 2   https://raw.githubusercontent.com/Prasadmadhus...                   No
# 3   https://raw.githubusercontent.com/Prasadmadhus...                   No
# 4   https://raw.githubusercontent.com/Prasadmadhus...                   No
# 5   https://raw.githubusercontent.com/Prasadmadhus...                   No
# 6   https://raw.githubusercontent.com/Prasadmadhus...                   No
# 7   https://raw.githubusercontent.com/Prasadmadhus...                   No
# 8   https://raw.githubusercontent.com/Prasadmadhus...                   No
# 9   https://raw.githubusercontent.com/Prasadmadhus...                   No
# 10  https://raw.githubusercontent.com/Prasadmadhus...                   No
# 11  https://raw.githubusercontent.com/Prasadmadhus...                  Yes
# 12  https://raw.githubusercontent.com/Prasadmadhus...                  Yes
# 13  https://raw.githubusercontent.com/Prasadmadhus...                   No
#
#    credential_id verify_url_status  \
# 0                              Yes
# 1                              Yes
# 2                              Yes
# 3                              Yes
# 4                              Yes
# 5                               No
# 6                              Yes
# 7                              Yes
# 8                              Yes
# 9                              Yes
# 10                             Yes
# 11    q4SGBQrHMW               Yes
# 12    WkJAmvlrPu               Yes
# 13                              No
#
#                                            verify_url   date_status       date
# 0   https://vliegbewijsonbemandeluchtvaartuigencon...  Valid Until: 2029-10-13
# 1   https://learningzone.eurocontrol.int/ilp/custo...  Valid Until: 2029-10-06
# 2   https://www.linkedin.com/learning/certificates...    Issued on: 2025-07-12
# 3   https://www.coursera.org/account/accomplishmen...    Issued on: 2025-03-07
# 4   https://www.coursera.org/account/accomplishmen...    Issued on: 2025-03-07
# 5                                                        Issued on: 2024-11-24
# 6   https://www.esri.com/training/TrainingRecord/C...    Issued on: 2024-10-19
# 7   https://www.coursera.org/account/accomplishmen...    Issued on: 2024-09-01
# 8   https://www.esri.com/training/TrainingRecord/C...    Issued on: 2024-05-19
# 9   https://www.esri.com/training/TrainingRecord/C...    Issued on: 2023-12-01
# 10  https://www.esri.com/training/TrainingRecord/C...    Issued on: 2023-10-11
# 11  https://open.uom.lk/lms/mod/customcert/verify_...    Issued on: 2023-05-14
# 12  https://open.uom.lk/lms/mod/customcert/verify_...    Issued on: 2023-05-14
# 13                                                       Issued on: 2022-11-01

# %%
# Convert DataFrame to JSON
json_data = df.to_dict(orient="records")
json_data
# Out:
# [{'id': 1,
#   'logo': 'https://raw.githubusercontent.com/Prasadmadhusanka/pm-data-files/main/images/certificates_logos/easa_logo.png',
#   'name': 'UAS Remote Pilot A2 Competency Certification',
#   'issued_by': 'EASA',
#   'certificate_url': 'https://raw.githubusercontent.com/Prasadmadhusanka/pm-data-files/main/images/certificates/easa_a2.png',
#   'credential_id_status': 'No',
#   'credential_id': '',
#   'verify_url_status': 'Yes',
#   'verify_url': 'https://vliegbewijsonbemandeluchtvaartuigencontroleren.rdw.nl/raadplegen?code=B426F763-8CA0-4667-8162-420FC1163AD5',
#   'date_status': 'Valid Until:',
#   'date': Timestamp('2029-10-13 00:00:00')},
#  {'id': 2,
#   'logo': 'https://raw.githubusercontent.com/Prasadmadhusanka/pm-data-files/main/images/certificates_logos/easa_logo.png',
#   'name': 'UAS Remote Pilot A1/A3 Competency Certification',
#   'issued_by': 'EASA',
#   'certificate_url': 'https://raw.githubusercontent.com/Prasadmadhusanka/pm-data-files/main/images/certificates/easa_a1a3.png',
#   'credential_id_status': 'No',
#   'credential_id': '',
#   'verify_url_status': 'Yes',
#   'verify_url': 'https://learningzone.eurocontrol.int/ilp/customs/Reports/DACUASComp/Certificate/Validation/14892890/?key=bd197379ead7b6a9ce1f1110c279be6ef32916708813a6aa5ca86cc466f68948',
#   'date_status': 'Valid Until:',
#   'date': Timestamp('2029-10-06 00:00:00')},
#  {'id': 3,
#   'logo': 'https://raw.githubusercontent.com/Prasadmadhusanka/pm-data-files/main/images/certificates_logos/linkedin_logo.png',
#   'name': 'FME Desktop: Data Translation for\nAEC',
#   'issued_by': 'LinkedIn',
#   'certificate_url': 'https://raw.githubusercontent.com/Prasadmadhusanka/pm-data-files/main/images/certificates/linkedin_fme.png',
#   'credential_id_status': 'No',
#   'credential_id': '',
#   'verify_url_status': 'Yes',
#   'verify_url': 'https://www.linkedin.com/learning/certificates/9f4aff9b54005fdb5ea536c3f379f1c3c0fcee53534964ee2934eb34751627e3',
#   'date_status': 'Issued on:',
#   'date': Timestamp('2025-07-12 00:00:00')},
#  {'id': 4,
#   'logo': 'https://raw.githubusercontent.com/Prasadmadhusanka/pm-data-files/main/images/certificates_logos/meta_logo.png',
#   'name': 'Meta Front - End Developer Professional Certificate',
#   'issued_by': 'Meta',
#   'certificate_url': 'https://raw.githubusercontent.com/Prasadmadhusanka/pm-data-files/main/images/certificates/meta_frontend.png',
#   'credential_id_status': 'No',
#   'credential_id': '',
#   'verify_url_status': 'Yes',
#   'verify_url': 'https://www.coursera.org/account/accomplishments/professional-cert/PBMDOFH4RSL9',
#   'date_status': 'Issued on:',
#   'date': Timestamp('2025-03-07 00:00:00')},
#  {'id': 5,
#   'logo': 'https://raw.githubusercontent.com/Prasadmadhusanka/pm-data-files/main/images/certificates_logos/meta_logo.png',
#   'name': 'Advanced React',
#   'issued_by': 'Meta',
#   'certificate_url': 'https://raw.githubusercontent.com/Prasadmadhusanka/pm-data-files/main/images/certificates/meta_advanced_react.png',
#   'credential_id_status': 'No',
#   'credential_id': '',
#   'verify_url_status': 'Yes',
#   'verify_url': 'https://www.coursera.org/account/accomplishments/verify/XQ7JABQ9S2HH',
#   'date_status': 'Issued on:',
#   'date': Timestamp('2025-03-07 00:00:00')},
#  {'id': 6,
#   'logo': 'https://raw.githubusercontent.com/Prasadmadhusanka/pm-data-files/main/images/certificates_logos/itc_logo.png',
#   'name': 'Geo Web App Building with OS Tools',
#   'issued_by': 'ITC - University of Twente',
#   'certificate_url': 'https://raw.githubusercontent.com/Prasadmadhusanka/pm-data-files/main/images/certificates/itc_geo_webapp.png',
#   'credential_id_status': 'No',
#   'credential_id': '',
#   'verify_url_status': 'No',
#   'verify_url': '',
#   'date_status': 'Issued on:',
#   'date': Timestamp('2024-11-24 00:00:00')},
#  {'id': 7,
#   'logo': 'https://raw.githubusercontent.com/Prasadmadhusanka/pm-data-files/main/images/certificates_logos/esri_logo.png',
#   'name': 'Make an Impact with Modern Geo Apps - MOOC',
#   'issued_by': 'Esri',
#   'certificate_url': 'https://raw.githubusercontent.com/Prasadmadhusanka/pm-data-files/main/images/certificates/esri_mordern_geo_apps.png',
#   'credential_id_status': 'No',
#   'credential_id': '',
#   'verify_url_status': 'Yes',
#   'verify_url': 'https://www.esri.com/training/TrainingRecord/Certificate/pliyanage_uji/663f6351dfcdba0f07ac28b9/-120',
#   'date_status': 'Issued on:',
#   'date': Timestamp('2024-10-19 00:00:00')},
#  {'id': 8,
#   'logo': 'https://raw.githubusercontent.com/Prasadmadhusanka/pm-data-files/main/images/certificates_logos/ibm_logo.png',
#   'name': 'IBM Data Science Professional Certificate',
#   'issued_by': 'IBM',
#   'certificate_url': 'https://raw.githubusercontent.com/Prasadmadhusanka/pm-data-files/main/images/certificates/ibm_datascience.png',
#   'credential_id_status': 'No',
#   'credential_id': '',
#   'verify_url_status': 'Yes',
#   'verify_url': 'https://www.coursera.org/account/accomplishments/professional-cert/DH2BOIB1K6XH',
#   'date_status': 'Issued on:',
#   'date': Timestamp('2024-09-01 00:00:00')},
#  {'id': 9,
#   'logo': 'https://raw.githubusercontent.com/Prasadmadhusanka/pm-data-files/main/images/certificates_logos/esri_logo.png',
#   'name': 'Cartography - MOOC',
#   'issued_by': 'Esri',
#   'certificate_url': 'https://raw.githubusercontent.com/Prasadmadhusanka/pm-data-files/main/images/certificates/esri_cartography.png',
#   'credential_id_status': 'No',
#   'credential_id': '',
#   'verify_url_status': 'Yes',
#   'verify_url': 'https://www.esri.com/training/TrainingRecord/Certificate/pliyanage_uji/65e450b0994f9072029de52e/-120',
#   'date_status': 'Issued on:',
#   'date': Timestamp('2024-05-19 00:00:00')},
#  {'id': 10,
#   'logo': 'https://raw.githubusercontent.com/Prasadmadhusanka/pm-data-files/main/images/certificates_logos/esri_logo.png',
#   'name': 'GIS for Climate Action - MOOC',
#   'issued_by': 'Esri',
#   'certificate_url': 'https://raw.githubusercontent.com/Prasadmadhusanka/pm-data-files/main/images/certificates/esri_gis_for_climate_action.png',
#   'credential_id_status': 'No',
#   'credential_id': '',
#   'verify_url_status': 'Yes',
#   'verify_url': 'https://www.esri.com/training/TrainingRecord/Certificate/pliyanage_uji/65338e86c2e83c0b26e644e9/-60',
#   'date_status': 'Issued on:',
#   'date': Timestamp('2023-12-01 00:00:00')},
#  {'id': 11,
#   'logo': 'https://raw.githubusercontent.com/Prasadmadhusanka/pm-data-files/main/images/certificates_logos/esri_logo.png',
#   'name': 'Spatial Data Science: The New Frontier in Analytics - MOOC',
#   'issued_by': 'Esri',
#   'certificate_url': 'https://raw.githubusercontent.com/Prasadmadhusanka/pm-data-files/main/images/certificates/esri_spatial_data_science_the_new_frontier_in_analytics.png',
#   'credential_id_status': 'No',
#   'credential_id': '',
#   'verify_url_status': 'Yes',
#   'verify_url': 'https://www.esri.com/training/TrainingRecord/Certificate/pliyanage_uji/64b911187640e8345a487546/-120',
#   'date_status': 'Issued on:',
#   'date': Timestamp('2023-10-11 00:00:00')},
#  {'id': 12,
#   'logo': 'https://raw.githubusercontent.com/Prasadmadhusanka/pm-data-files/main/images/certificates_logos/uom_logo.png',
#   'name': 'Python Programming',
#   'issued_by': 'University of Moratuwa',
#   'certificate_url': 'https://raw.githubusercontent.com/Prasadmadhusanka/pm-data-files/main/images/certificates/uom_python.png',
#   'credential_id_status': 'Yes',
#   'credential_id': 'q4SGBQrHMW',
#   'verify_url_status': 'Yes',
#   'verify_url': 'https://open.uom.lk/lms/mod/customcert/verify_certificate.php',
#   'date_status': 'Issued on:',
#   'date': Timestamp('2023-05-14 00:00:00')},
#  {'id': 13,
#   'logo': 'https://raw.githubusercontent.com/Prasadmadhusanka/pm-data-files/main/images/certificates_logos/uom_logo.png',
#   'name': 'Front - End Web Development',
#   'issued_by': 'University of Moratuwa',
#   'certificate_url': 'https://raw.githubusercontent.com/Prasadmadhusanka/pm-data-files/main/images/certificates/uom_fronend.png',
#   'credential_id_status': 'Yes',
#   'credential_id': 'WkJAmvlrPu',
#   'verify_url_status': 'Yes',
#   'verify_url': 'https://open.uom.lk/lms/mod/customcert/verify_certificate.php',
#   'date_status': 'Issued on:',
#   'date': Timestamp('2023-05-14 00:00:00')},
#  {'id': 14,
#   'logo': 'https://raw.githubusercontent.com/Prasadmadhusanka/pm-data-files/main/images/certificates_logos/unmappers_logo.png',
#   'name': 'OpenStreetMap and Humanitarian Mapping',
#   'issued_by': 'UN Mappers',
#   'certificate_url': 'https://raw.githubusercontent.com/Prasadmadhusanka/pm-data-files/main/images/certificates/unmappers.png',
#   'credential_id_status': 'No',
#   'credential_id': '',
#   'verify_url_status': 'No',
#   'verify_url': '',
#   'date_status': 'Issued on:',
#   'date': Timestamp('2022-11-01 00:00:00')}]

# %%
import json
from datetime import datetime

class DateOnlyEncoder(json.JSONEncoder):
    def default(self, obj):
        if isinstance(obj, datetime):
            # Format as "Month Day, Year" (e.g., "November 13, 1990")
            return obj.strftime("%B %d, %Y")
        return super().default(obj)


with open("../json_files/licenses_certificates.json", "w", encoding="utf-8") as json_file:
    json.dump(json_data, json_file, indent=4, cls=DateOnlyEncoder)
